# %%
odom_data = {
            'single_track': {'positions': [], 'orientations': []},
            'double_track': {'positions': [], 'orientations': []},
            'yaw_rate': {'positions': [], 'orientations': []},
            }

for key in odom_data.keys():
    print(f'{key}')
# Out:
# single_track
# double_track
# yaw_rate
